# %% [markdown]
# ## Laboratorio 1
#
# # 01/09/2026
#
# # Jorge Nieves Flores

# %%
print (" Mi primer sistema inteligente")
Nombre = input ("Escriba su nombre empezando por apellido paterno")
Matricula = input ("Escriba su matricula")
Promedio = float(input ("Escribe tu promedio"))
# Out:
#  Mi primer sistema inteligente
# Escriba su nombre empezando por apellido paterno Nieves Flores Jorge
# Escriba su matricula 20243L601058
# Escribe tu promedio 4.0

# %%
print ("Datos almacenados")
print ("Nombre: ", Nombre)
print ("Matricula: ", Matricula)
print ("Promedio: ", Promedio)
# Out:
# Datos almacenados
# Nombre:  Nieves Flores Jorge
# Matricula:  20243L601058
# Promedio:  4.0

# %% [markdown]
# # Reglas

# %%
if Promedio >=8.0 and Promedio <10:
        print("Excelente desempeño")
elif Promedio <8.0 and Promedio >=7.0:
    print("Echale ganas, puedes mejorar")
elif Promedio <7.0 and Promedio >=6.0:
    print("Necesitas ayuda")
else:
    print("Date de baja")
# Out:
# Date de baja
