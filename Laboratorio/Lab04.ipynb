# %%
### Definicion de Variables
disponibilidad = False # No esta disponible el servidor principal
latencia = True # Si la latencia supera el limite establecido
limite = True # Si la perdida de paquetes supera el limite permitido
trafico = True # Si el trafico de red es anormalmente alto
respaldo = False # No el servidor de respaldo no esta disponible
monitoreo = True # Si el sistema de monitoreo esta activo

# %%
CondicionCritica = (disponibilidad==False and latencia==True and limite==True and trafico==True and respaldo==False and monitoreo==True)

# %%
print ("El estado del sistema es critico"), CondicionCritica
# Out:
# El estado del sistema es critico
# (None, True)

# %%
print (" == Sistema de analisis de red ==")
print ("Development by Jorge")

disponibilidad = input("El servidor principal se encuentra disponible? (s/n): ").lower() == "n"
latencia = input("La latencia supera el limite establecido? (s/n): ").lower() == "s"
limite = input("La perdida de paquetes supera el limite permitido? (s/n): ").lower() == "s"
trafico = input("El trafico de red es anormalmente alto? (s/n): ").lower() == "s"
respaldo = input("El servidor de respaldo se encuentra disponibe? (s/n): ").lower() == "n"
monitoreo = input("El sistema de monitoreo esta activo? (s/n): ").lower() == "s"

CondicionCritica = (disponibilidad==False and latencia==True and limite==True and trafico==True and respaldo==False and monitoreo==True)

print ("Decision del Sistema")
if CondicionCritica == True :
    print("El Sistema se encuentra en optimas condiciones")
else:
    print("El Sistema se encuentra en estado critico")
# Out:
#  == Sistema de analisis de red ==
# Development by Jorge
# El servidor principal se encuentra disponible? (s/n):  s
# La latencia supera el limite establecido? (s/n):  s
# La perdida de paquetes supera el limite permitido? (s/n):  s
# El trafico de red es anormalmente alto? (s/n):  s
# El servidor de respaldo se encuentra disponibe? (s/n):  s
# El sistema de monitoreo esta activo? (s/n):  s
# Decision del Sistema
# El Sistema se encuentra en optimas condiciones
